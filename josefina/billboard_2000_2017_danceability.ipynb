# %%
#Dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Pulling the csv file
bllb = "billboard_2000_2017_spotify_clean.csv"
bllb_df = pd.read_csv(bllb)
bllb_df.head(2)
# Out:
#      date  year                                              title  \
# 0  1/8/00  2000  The Christmas Song (Chestnuts Roasting On An O...
# 1  9/2/00  2000                             Oops!...I Did It Again
#
#              simple_title              artist         main_artist  peak_pos  \
# 0      the christmas song  christina aguilera  christina aguilera        18
# 1  oops!...i did it again      britney spears      britney spears         9
#
#    last_pos  weeks  rank  ... acousticness instrumentalness time_signature  \
# 0        18      4    18  ...        0.884                0              4
# 1        90     20    96  ...          0.3         1.77E-05              4
#
#   danceability key duration_ms loudness valence mode  \
# 0        0.392   2      264960   -8.452   0.147    1
# 1        0.751   1      211160   -5.444   0.894    0
#
#                                               lyrics
# 0  Chestnuts roasting on an open fire\nJack Frost...
# ...

# %%
#Creating DataFrame to work and cleaning columns
bllb_df.drop(['date', 'simple_title', 'artist', 'last_pos', 'change', 'spotify_link',
               'spotify_id', 'video_link', 'genre', 'analysis_url', 'liveness', 'speechiness', 
               'acousticness', 'instrumentalness', 'time_signature', 'key', 'duration_ms', 'loudness', 
               'valence', 'mode', 'lyrics'], axis=1, inplace=True)
#Renaming columns for presentation
bllb_df.rename(columns= {"year":"Year", "title":"Track_Title", "main_artist": "Main_Artist",
                          "peak_pos": "Peak_Position", "weeks": "Weeks", "rank":"Rank", 
                          "broad_genre": "Broad_Genre", "energy":"Energy_Factor", "tempo":"Tempo", 
                          "danceability":"Danceability"}, inplace=True)
#Changing the format of the two columns needed for the analysis to numbers
bllb_df["Tempo"] = pd.to_numeric(bllb_df["Tempo"], errors='coerce')
bllb_df["Danceability"] = pd.to_numeric(bllb_df["Danceability"], errors='coerce')
bllb_df.dtypes
# Out:
# Year               int64
# Track_Title       object
# Main_Artist       object
# Peak_Position      int64
# Weeks              int64
# Rank               int64
# Broad_Genre       object
# Energy_Factor     object
# Tempo            float64
# Danceability     float64
# dtype: object

# %%
#Filtering by year to group by genres on each year
b2000 = bllb_df.loc[bllb_df["Year"]==2000,:]

#Creating individual DataFrames for each year. Most likely could be accomplished by using a for loop or a more efficient way...
top_2000 = b2000.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2001 = bllb_df.loc[bllb_df["Year"]==2001,:]
top_2001 = b2001.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2002 = bllb_df.loc[bllb_df["Year"]==2002,:]
top_2002 = b2002.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2003 = bllb_df.loc[bllb_df["Year"]==2003,:]
top_2003 = b2003.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2004 = bllb_df.loc[bllb_df["Year"]==2004,:]
top_2004 = b2004.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2005 = bllb_df.loc[bllb_df["Year"]==2005,:]
top_2005 = b2005.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2006 = bllb_df.loc[bllb_df["Year"]==2006,:]
top_2006 = b2006.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2007 = bllb_df.loc[bllb_df["Year"]==2007,:]
top_2007 = b2007.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2008 = bllb_df.loc[bllb_df["Year"]==2008,:]
top_2008 = b2008.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2009 = bllb_df.loc[bllb_df["Year"]==2009,:]
top_2009 = b2009.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2010 = bllb_df.loc[bllb_df["Year"]==2010,:]
top_2010 = b2010.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2011 = bllb_df.loc[bllb_df["Year"]==2011,:]
top_2011 = b2011.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2012 = bllb_df.loc[bllb_df["Year"]==2012,:]
top_2012 = b2012.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2013 = bllb_df.loc[bllb_df["Year"]==2013,:]
top_2013 = b2013.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2014 = bllb_df.loc[bllb_df["Year"]==2014,:]
top_2014 = b2014.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2015 = bllb_df.loc[bllb_df["Year"]==2015,:]
top_2015 = b2015.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2016 = bllb_df.loc[bllb_df["Year"]==2016,:]
top_2016 = b2016.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
b2017 = bllb_df.loc[bllb_df["Year"]==2017,:]
top_2017 = b2017.groupby(["Broad_Genre", "Year"]).agg({"Track_Title":"count", 
                                                  "Energy_Factor":"max",
                                                  "Tempo":"mean",
                                                  "Danceability":"mean"})

# %%
#Colapsing the information back to one single dataframe based on the measure being analyzed, working now with danceability
dance_df = pd.DataFrame({
    "Genre":["Country", "EDM", "Pop", "R&B", "Rap", "Rock", "Unknown"],
    "2000_hits": (top_2000["Danceability"].to_list()),
    "2001_hits": (top_2001["Danceability"].to_list()),
    "2002_hits": (top_2002["Danceability"].to_list()),
    "2003_hits": (top_2003["Danceability"].to_list()),
    "2004_hits": (top_2004["Danceability"].to_list()),
    "2005_hits": (top_2005["Danceability"].to_list()),
    "2006_hits": (top_2006["Danceability"].to_list()),
    "2007_hits": (top_2007["Danceability"].to_list()),
    "2008_hits": (top_2008["Danceability"].to_list()),
    "2009_hits": (top_2009["Danceability"].to_list()),
    "2010_hits": (top_2010["Danceability"].to_list()),
    "2011_hits": (top_2011["Danceability"].to_list()),
    "2012_hits": (top_2012["Danceability"].to_list()),
    "2013_hits": (top_2013["Danceability"].to_list()),
    "2014_hits": (top_2014["Danceability"].to_list()),
    "2015_hits": (top_2015["Danceability"].to_list()),
    "2016_hits": (top_2016["Danceability"].to_list()),
    "2017_hits": (top_2017["Danceability"].to_list()),
})
dance_df.head(2)
# Out:
#      Genre  2000_hits  2001_hits  2002_hits  2003_hits  2004_hits  2005_hits  \
# 0  Country   0.586242   0.576190    0.55486   0.567847   0.560774   0.568797
# 1      EDM   0.719000   0.577833    0.65200   0.571333   0.650800   0.573667
#
#    2006_hits  2007_hits  2008_hits  2009_hits  2010_hits  2011_hits  \
# 0   0.552587    0.54275   0.540156   0.549264   0.558220     0.5506
# 1   0.554400    0.63300   0.691909   0.680833   0.676818     0.6485
#
#    2012_hits  2013_hits  2014_hits  2015_hits  2016_hits  2017_hits
# 0   0.555958   0.555107   0.552639   0.564176   0.551324   0.581100
# 1   0.631500   0.627438   0.629316   0.590957   0.632655   0.665667

# %%
#Setting the Genre column as an index to use on the plots
dance_df.set_index("Genre", inplace=True)
dance_df
# Out:
#          2000_hits  2001_hits  2002_hits  2003_hits  2004_hits  2005_hits  \
# Genre
# Country   0.586242   0.576190   0.554860   0.567847   0.560774   0.568797
# EDM       0.719000   0.577833   0.652000   0.571333   0.650800   0.573667
# Pop       0.654094   0.636727   0.671156   0.618000   0.539737   0.577579
# R&B       0.705674   0.717090   0.683776   0.693391   0.713821   0.720444
# Rap       0.784490   0.725479   0.694634   0.662397   0.698222   0.688628
# Rock      0.547524   0.562459   0.495000   0.552042   0.544136   0.501294
# Unknown   0.668800   0.710267   0.632778   0.736929   0.741000   0.652222
#
#          2006_hits  2007_hits  2008_hits  2009_hits  2010_hits  2011_hits  \
# Genre
# Country   0.552587   0.542750   0.540156   0.549264   0.558220   0.550600
# EDM       0.554400   0.633000   0.691909   0.680833   0.676818   0.648500
# Pop       0.608208   0.616938   0.583091   0.555009   0.575689   0.585174
# ...

# %%
#Setting the axis for the plot lines, to look at genre trends over the years
years = np.arange(2000, 2018,1)
Country, = plt.plot(years, dance_df.loc["Country", dance_df.columns], color="green")
EDM, = plt.plot(years, dance_df.loc["EDM", dance_df.columns], color="blue")
Pop, = plt.plot(years, dance_df.loc["Pop", dance_df.columns], color="red")
RandB, = plt.plot(years, dance_df.loc["R&B", dance_df.columns], color="yellow")
Rap, = plt.plot(years, dance_df.loc["Rap", dance_df.columns], color="orange")
Rock, = plt.plot(years, dance_df.loc["Rock", dance_df.columns], color="purple")
Unknown, = plt.plot(years, dance_df.loc["Unknown", dance_df.columns], color="gray")

#Formatting the tickers in plot to integers
import matplotlib.ticker
locator = matplotlib.ticker.MultipleLocator(2)
plt.gca().xaxis.set_major_locator(locator)
formatter = matplotlib.ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

plt.legend(handles=[Country, EDM, Pop, RandB, Rap, Rock, Unknown], loc="best")
#Setting the axis and plot titles
plt.title("Danceability by genre over the years")
plt.xlabel("Years reviewed")
plt.ylabel("Danceability factor")
#Printing and saving plot
plt.show()
plt.savefig("Danceability factor by genre over the years")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
