# %%
import requests
import json
from config import api_last_fm

api_key = api_last_fm 
url = "http://ws.audioscrobbler.com/2.0/"   #?method=chart.gettoptags"

method = "chart.gettopartists"
params = {
    "method": method,
    "api_key": api_key,
    "format": "json"
}

tags = requests.get(url, params=params)
tags_json = tags.json()
print(tags.url)
# Out:
# http://ws.audioscrobbler.com/2.0/?method=chart.gettopartists&api_key=6eed7eabfeadf7e13784e1afec29ed52&format=json

# %%
artist_response = tags_json["artists"]["artist"]
artist_response
# Out:
# [{'name': 'Billie Eilish',
#   'playcount': '34902689',
#   'listeners': '583120',
#   'mbid': '',
#   'url': 'https://www.last.fm/music/Billie+Eilish',
#   'streamable': '0',
#   'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'}]},
#  {'name': 'Lana Del Rey',
#   'playcount': '230845769',
#   'listeners': '1951246',
#   'mbid': 'b7539c32-53e7-4908-bda3-81449c367da6',
#   'url': 'https://www.last.fm/music/Lana+Del+Rey',
# ...

# %%
import pandas as pd

artist_response_df = pd.DataFrame(artist_response)
artist_response_df.head()
# Out:
#             name  playcount listeners                                  mbid  \
# 0  Billie Eilish   34902689    583120
# 1   Lana Del Rey  230845769   1951246  b7539c32-53e7-4908-bda3-81449c367da6
# 2   Taylor Swift  194814437   2287545  20244d07-534f-4eff-b4d4-930878889970
# 3     Ed Sheeran   92329231   1713168  b8a7c51f-362c-4dcb-a259-bc6e0095f0a6
# 4  Ariana Grande  123231354   1161500  f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387
#
#                                        url streamable  \
# 0  https://www.last.fm/music/Billie+Eilish          0
# 1   https://www.last.fm/music/Lana+Del+Rey          0
# 2   https://www.last.fm/music/Taylor+Swift          0
# 3     https://www.last.fm/music/Ed+Sheeran          0
# 4  https://www.last.fm/music/Ariana+Grande          0
#
#                                                image
# 0  [{'#text': 'https://lastfm-img2.akamaized.net/...
# 1  [{'#text': 'https://lastfm-img2.akamaized.net/...
# 2  [{'#text': 'https://lastfm-img2.akamaized.net/...
# ...

# %%
artist_response_df.drop(columns=["image", "mbid"], inplace=True)
artist_response_df.head(5)
# Out:
#             name  playcount listeners  \
# 0  Billie Eilish   34902689    583120
# 1   Lana Del Rey  230845769   1951246
# 2   Taylor Swift  194814437   2287545
# 3     Ed Sheeran   92329231   1713168
# 4  Ariana Grande  123231354   1161500
#
#                                        url streamable
# 0  https://www.last.fm/music/Billie+Eilish          0
# 1   https://www.last.fm/music/Lana+Del+Rey          0
# 2   https://www.last.fm/music/Taylor+Swift          0
# 3     https://www.last.fm/music/Ed+Sheeran          0
# 4  https://www.last.fm/music/Ariana+Grande          0

# %%
artist_response_df.to_csv("top_artist.csv", encoding="utf-8", index=False, header=True)
