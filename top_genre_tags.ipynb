# %%
import requests
import json

api_key = "6eed7eabfeadf7e13784e1afec29ed52"
url = "http://ws.audioscrobbler.com/2.0/"   #?method=chart.gettoptags"

method = "chart.gettoptags"
params = {
    "method": method,
    "api_key": api_key,
    "format": "json"
}

tags = requests.get(url, params=params)
tags_json = tags.json()
print(tags.url)
# Out:
# http://ws.audioscrobbler.com/2.0/?method=chart.gettoptags&api_key=6eed7eabfeadf7e13784e1afec29ed52&format=json

# %%
tags_response = tags_json["tags"]["tag"]
tags_response
# Out:
# [{'name': 'rock',
#   'url': 'https://www.last.fm/tag/rock',
#   'reach': '394676',
#   'taggings': '3965297',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'electronic',
#   'url': 'https://www.last.fm/tag/electronic',
#   'reach': '253057',
#   'taggings': '2354576',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'seen live',
#   'url': 'https://www.last.fm/tag/seen+live',
#   'reach': '81678',
#   'taggings': '2137591',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'alternative',
#   'url': 'https://www.last.fm/tag/alternative',
#   'reach': '261148',
#   'taggings': '2092825',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'indie',
#   'url': 'https://www.last.fm/tag/indie',
#   'reach': '252609',
#   'taggings': '2012769',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'pop',
#   'url': 'https://www.last.fm/tag/pop',
#   'reach': '224703',
#   'taggings': '1962214',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'female vocalists',
#   'url': 'https://www.last.fm/tag/female+vocalists',
#   'reach': '167679',
#   'taggings': '1598269',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'metal',
#   'url': 'https://www.last.fm/tag/metal',
#   'reach': '155198',
#   'taggings': '1255620',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'alternative rock',
#   'url': 'https://www.last.fm/tag/alternative+rock',
#   'reach': '166462',
#   'taggings': '1161819',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'jazz',
#   'url': 'https://www.last.fm/tag/jazz',
#   'reach': '146163',
#   'taggings': '1142722',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'classic rock',
#   'url': 'https://www.last.fm/tag/classic+rock',
#   'reach': '136546',
#   'taggings': '1138177',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'ambient',
#   'url': 'https://www.last.fm/tag/ambient',
#   'reach': '143551',
#   'taggings': '1045403',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'experimental',
#   'url': 'https://www.last.fm/tag/experimental',
#   'reach': '138535',
#   'taggings': '1042744',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'folk',
#   'url': 'https://www.last.fm/tag/folk',
#   'reach': '147002',
#   'taggings': '910624',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'punk',
#   'url': 'https://www.last.fm/tag/punk',
#   'reach': '141564',
#   'taggings': '874819',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'indie rock',
#   'url': 'https://www.last.fm/tag/indie+rock',
#   'reach': '133004',
#   'taggings': '870470',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'hard rock',
#   'url': 'https://www.last.fm/tag/hard+rock',
#   'reach': '113696',
#   'taggings': '853912',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'Hip-Hop',
#   'url': 'https://www.last.fm/tag/Hip-Hop',
#   'reach': '126141',
#   'taggings': '852075',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'instrumental',
#   'url': 'https://www.last.fm/tag/instrumental',
#   'reach': '122716',
#   'taggings': '835158',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'singer-songwriter',
#   'url': 'https://www.last.fm/tag/singer-songwriter',
#   'reach': '107870',
#   'taggings': '827735',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'black metal',
#   'url': 'https://www.last.fm/tag/black+metal',
#   'reach': '61301',
#   'taggings': '824542',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'dance',
#   'url': 'https://www.last.fm/tag/dance',
#   'reach': '131709',
#   'taggings': '794952',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': '80s',
#   'url': 'https://www.last.fm/tag/80s',
#   'reach': '99773',
#   'taggings': '773325',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'Progressive rock',
#   'url': 'https://www.last.fm/tag/Progressive+rock',
#   'reach': '95084',
#   'taggings': '719019',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'death metal',
#   'url': 'https://www.last.fm/tag/death+metal',
#   'reach': '70732',
#   'taggings': '705570',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'heavy metal',
#   'url': 'https://www.last.fm/tag/heavy+metal',
#   'reach': '89345',
#   'taggings': '694635',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'hardcore',
#   'url': 'https://www.last.fm/tag/hardcore',
#   'reach': '96715',
#   'taggings': '684967',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'british',
#   'url': 'https://www.last.fm/tag/british',
#   'reach': '92517',
#   'taggings': '681858',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'soul',
#   'url': 'https://www.last.fm/tag/soul',
#   'reach': '99619',
#   'taggings': '665750',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'chillout',
#   'url': 'https://www.last.fm/tag/chillout',
#   'reach': '102971',
#   'taggings': '645501',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'electronica',
#   'url': 'https://www.last.fm/tag/electronica',
#   'reach': '101265',
#   'taggings': '629230',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'Classical',
#   'url': 'https://www.last.fm/tag/Classical',
#   'reach': '73451',
#   'taggings': '558662',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'industrial',
#   'url': 'https://www.last.fm/tag/industrial',
#   'reach': '82801',
#   'taggings': '552034',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'Soundtrack',
#   'url': 'https://www.last.fm/tag/Soundtrack',
#   'reach': '83438',
#   'taggings': '551652',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'rap',
#   'url': 'https://www.last.fm/tag/rap',
#   'reach': '102167',
#   'taggings': '551160',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'blues',
#   'url': 'https://www.last.fm/tag/blues',
#   'reach': '94985',
#   'taggings': '541952',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'punk rock',
#   'url': 'https://www.last.fm/tag/punk+rock',
#   'reach': '96732',
#   'taggings': '540845',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'thrash metal',
#   'url': 'https://www.last.fm/tag/thrash+metal',
#   'reach': '61814',
#   'taggings': '487177',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': '90s',
#   'url': 'https://www.last.fm/tag/90s',
#   'reach': '56408',
#   'taggings': '476857',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'acoustic',
#   'url': 'https://www.last.fm/tag/acoustic',
#   'reach': '109653',
#   'taggings': '472872',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'metalcore',
#   'url': 'https://www.last.fm/tag/metalcore',
#   'reach': '66307',
#   'taggings': '469471',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'psychedelic',
#   'url': 'https://www.last.fm/tag/psychedelic',
#   'reach': '76989',
#   'taggings': '468150',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'japanese',
#   'url': 'https://www.last.fm/tag/japanese',
#   'reach': '48026',
#   'taggings': '454148',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'post-rock',
#   'url': 'https://www.last.fm/tag/post-rock',
#   'reach': '64332',
#   'taggings': '437452',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'german',
#   'url': 'https://www.last.fm/tag/german',
#   'reach': '58823',
#   'taggings': '429441',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'Progressive metal',
#   'url': 'https://www.last.fm/tag/Progressive+metal',
#   'reach': '61581',
#   'taggings': '428979',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'funk',
#   'url': 'https://www.last.fm/tag/funk',
#   'reach': '81808',
#   'taggings': '419790',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'hip hop',
#   'url': 'https://www.last.fm/tag/hip+hop',
#   'reach': '75864',
#   'taggings': '419369',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'new wave',
#   'url': 'https://www.last.fm/tag/new+wave',
#   'reach': '63262',
#   'taggings': '414370',
#   'streamable': '1',
#   'wiki': {}},
#  {'name': 'trance',
#   'url': 'https://www.last.fm/tag/trance',
#   'reach': '64044',
#   'taggings': '410368',
#   'streamable': '1',
#   'wiki': {}}]

# %%
import pandas as pd

tags_response_df = pd.DataFrame(tags_response)
tags_response_df.head()
# Out:
#           name   reach streamable taggings  \
# 0         rock  394676          1  3965297
# 1   electronic  253057          1  2354576
# 2    seen live   81678          1  2137591
# 3  alternative  261148          1  2092825
# 4        indie  252609          1  2012769
#
#                                    url wiki
# 0         https://www.last.fm/tag/rock   {}
# 1   https://www.last.fm/tag/electronic   {}
# 2    https://www.last.fm/tag/seen+live   {}
# 3  https://www.last.fm/tag/alternative   {}
# 4        https://www.last.fm/tag/indie   {}

# %%
tags_response_df.to_csv("top_genre_tags.csv", encoding="utf-8", index=False, header=True)

# %%
top_tags = tags_response_df.head(5)
top_tags
# Out:
#           name   reach streamable taggings  \
# 0         rock  394676          1  3965297
# 1   electronic  253057          1  2354576
# 2    seen live   81678          1  2137591
# 3  alternative  261148          1  2092825
# 4        indie  252609          1  2012769
#
#                                    url wiki
# 0         https://www.last.fm/tag/rock   {}
# 1   https://www.last.fm/tag/electronic   {}
# 2    https://www.last.fm/tag/seen+live   {}
# 3  https://www.last.fm/tag/alternative   {}
# 4        https://www.last.fm/tag/indie   {}

# %%
top_tags.dtypes
# Out:
# name          object
# reach         object
# streamable    object
# taggings      object
# url           object
# wiki          object
# dtype: object

# %%
values = top_tags["taggings"].astype(str).astype(int)
values
# Out:
# 0    3965297
# 1    2354576
# 2    2137591
# 3    2092825
# 4    2012769
# Name: taggings, dtype: int32

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

tags = values
x_axis = np.arange(len(tags))
plt.bar(x_axis, tags, color="g", alpha=0.5, align="center")
plt.title("Genre taggings in users streamed music from IF")
plt.xlabel("Genres")
plt.ylabel("Taggins")
tick_values = [value for value in x_axis]
plt.xticks(tick_values, ["Rock", "Electronic", "Seen Live", "Alternative", "Indie"])
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig("Top_genre_tags")
